# %%
import requests, pprint
from IPython.display import clear_output as co
from datetime import datetime

class Partners:
    def __init__(self,first,last,email, country, avail_dates):
        self.first = first
        self.last = last
        self.email = email
        self.country = country
        self.dates = avail_dates
class Attendees:
    _list = []
    
    @classmethod
    def get_info(self,idx):
        l = []
        res = requests.get(f'https://ct-api-challenge.herokuapp.com/').json()['partners']
        f_name = res[idx]['firstName']
        l_name = res[idx]['lastName']
        email = res[idx]['email']
        country = res[idx]['country']
        for i in res[idx]['availableDates']:
            l.append(i)
        p = Partners(f_name,l_name,email,country,l)
        return p
    
    @classmethod
    def bestDate_byCountry(self,l_of_partners,country):
        mostOcc = {}
        count = 0
        for p in l_of_partners:
            if p.country == country:
                for i in p.dates:
                    if i not in mostOcc:
                        mostOcc[i]=0
        for i in mostOcc:
            for p in l_of_partners:
                if p.country == country:
                    for k in p.dates:
                        if i in k:
                            count += 1
            mostOcc[i] = count
            count = 0
        
        sorted_mO = sorted(mostOcc.items(), key=lambda kv:kv[1])
        for i in range(len(sorted_mO)):
            first_date = datetime.strptime(sorted_mO[-i-1][0], '%Y-%m-%d')
            second_date = datetime.strptime(sorted_mO[-i][0], '%Y-%m-%d')
            diff = second_date - first_date
            if diff.days == 1:
                best_date = sorted_mO[-i-1][0]
                break
        return best_date
    
    @classmethod
    def run(self):
        l_partner = []
        l_country = {}
        res = requests.get(f'https://ct-api-challenge.herokuapp.com/').json()['partners']
        for i in range(len(res)):
            l_partner.append(self.get_info(i))
        
        for i in l_partner:
            if i.country not in l_country:
                l_country[i.country] = {}
        done = False
        while not done:
            attendees = 0
            inp = input("Which country would you like to see the available attendees? press q to quit: ").title()
            co()
            print("="*50)
            if inp == 'q':
                print("Goodbye!")
                done = True
            else:
                for i in l_partner:
                    date = self.bestDate_byCountry(l_partner,inp)
                    for d in i.dates:
                        if date == d:
                            if i.email not in l_country[inp]:
                                p_data = {
                                        'Email': i.email,
                                        'First Name': i.first,
                                        'Last Name': i.last,
                                        }
                                l_country[i.country].update(p_data)
                                attendees += 1
                                print(l_country[i.country])
        #         print(f'The best date for {l_country} is {date}')
                n_country = list(l_country)
                print("="*50)
                print("Available attendees:",attendees)
                print(f"The country {inp}'s best available date is: {date} ")
                print(f'Here are all the emails, first and last names available to attend this date')
                print("="*50)

Attendees.run()
# Out:
# ==================================================
# {'Email': 'rrojero@codingtemple.com', 'First Name': 'Randy', 'Last Name': 'Rojero'}
# {'Email': 'nshier@codingtemple.com', 'First Name': 'Natividad', 'Last Name': 'Shier'}
# {'Email': 'tdevoll@codingtemple.com', 'First Name': 'Toccara', 'Last Name': 'Devoll'}
# {'Email': 'lgritton@codingtemple.com', 'First Name': 'Lin', 'Last Name': 'Gritton'}
# {'Email': 'elizarrago@codingtemple.com', 'First Name': 'Edris', 'Last Name': 'Lizarrago'}
# {'Email': 'ehartly@codingtemple.com', 'First Name': 'Evie', 'Last Name': 'Hartly'}
# {'Email': 'mhutley@codingtemple.com', 'First Name': 'Marco', 'Last Name': 'Hutley'}
# {'Email': 'rveyna@codingtemple.com', 'First Name': 'Roseline', 'Last Name': 'Veyna'}
# {'Email': 'abending@codingtemple.com', 'First Name': 'Annett', 'Last Name': 'Bending'}
# {'Email': 'agewant@codingtemple.com', 'First Name': 'Antwan', 'Last Name': 'Gewant'}
# {'Email': 'csabori@codingtemple.com', 'First Name': 'Carol', 'Last Name': 'Sabori'}
# {'Email': 'jtrieger@codingtemple.com', 'First Name': 'Joni', 'Last Name': 'Trieger'}
# {'Email': 'rradoslovich@codingtemple.com', 'First Name': 'Richard', 'Last Name': 'Radoslovich'}
# {'Email': 'manglebrandt@codingtemple.com', 'First Name': 'Markus', 'Last Name': 'Anglebrandt'}
# {'Email': 'ckollmorgen@codingtemple.com', 'First Name': 'Chanell', 'Last Name': 'Kollmorgen'}
# {'Email': 'thouse@codingtemple.com', 'First Name': 'Tomas', 'Last Name': 'House'}
# {'Email': 'lalway@codingtemple.com', 'First Name': 'Leatha', 'Last Name': 'Alway'}
# {'Email': 'hvazzana@codingtemple.com', 'First Name': 'Henry', 'Last Name': 'Vazzana'}
# {'Email': 'ltacadina@codingtemple.com', 'First Name': 'Lilian', 'Last Name': 'Tacadina'}
# {'Email': 'csultemeier@codingtemple.com', 'First Name': 'Chery', 'Last Name': 'Sultemeier'}
# {'Email': 'scowgill@codingtemple.com', 'First Name': 'Shannon', 'Last Name': 'Cowgill'}
# {'Email': 'jeffner@codingtemple.com', 'First Name': 'Julieann', 'Last Name': 'Effner'}
# {'Email': 'csibille@codingtemple.com', 'First Name': 'Carmon', 'Last Name': 'Sibille'}
# {'Email': 'dmaneafaiga@codingtemple.com', 'First Name': 'Daniella', 'Last Name': 'Maneafaiga'}
# ==================================================
# Available attendees: 24
# The country Canada's best available date is: 2017-06-26
# Here are all the emails, first and last names available to attend this date
# ==================================================
